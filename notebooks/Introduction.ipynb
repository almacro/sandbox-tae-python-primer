# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# array math
x = np.array([1, 2, 3, 4])
print("mean:", x.mean())
# Out:
# mean: 2.5

# %%
# a tiny plot
t = np.linspace(0.0, 2.0 * np.pi, 200)
plt.plot(t, np.sin(t))
plt.title("Hello, Colab")
plt.show()

# %%
x = np.linspace(0.0, 2.0 * np.pi, 200)
plt.plot(x, np.sin(x))
plt.savefig('hello_line.png', dpi=150)
